# %%
import matplotlib.pyplot as plt
import torch

import sys
sys.path.append("../")
sys.path.append("../src")

from src.deepqlearning import DeepQlearning, NeuralNetwork
from src.agent import Player

# %% [markdown]
# # Set up agents

# %%
dql = torch.load('../models/deepqlearning/model_tmp.pt')
ql = torch.load('../models/qlearning/model_tmp.pt')

# %% [markdown]
# # Analyze DeepQ training

# %%
dql.plot_training_stats()
plt.show()

# %% [markdown]
# # Analyze Q training

# %%
ql.plot_training_stats()
plt.show()

# %% [markdown]
# # Look at games played by the agents

# %%
# DeepQlearning against himself
dql.play()

# %%
# Qlearning against himself
ql.play()

# %%
# DeepQlearning against random player
"""
player_1 means that the random player plays 2nd
change to player_0 to play first
"""

dql.play_random('player_1')

# %%
# Qlearning against random player
"""
player_1 means that the random player plays 2nd
change
"""

ql.play_random('player_1')

# %%
# Play yourself against the trained DeepQlearning agent
"""
player_1 means that you play 2nd
change to player_0 to play first
"""

dql.play_user('player_1')
# Out:
# Choose a column to play in (between 0 and 6)
# Choose a column to play in (between 0 and 6)
# Choose a column to play in (between 0 and 6)
# Choose a column to play in (between 0 and 6)
# Choose a column to play in (between 0 and 6)
# Choose a column to play in (between 0 and 6)
# Choose a column to play in (between 0 and 6)
# Sorry, you lost against our agent.

# %%
# Play yourself against the trained Qlearning agent
"""
player_1 means that you play 2nd
change to player_0 to play first
"""

ql.play_user('player_1')
# Out:
# Choose a column to play in (between 0 and 6)
# Choose a column to play in (between 0 and 6)
# Choose a column to play in (between 0 and 6)
# Choose a column to play in (between 0 and 6)
# Choose a column to play in (between 0 and 6)
# Sorry, you lost against our agent.

# %% [markdown]
# # Compare model performances
